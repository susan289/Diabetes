# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from scipy import stats
# %matplotlib inline

# %%
df = pd.read_csv('model_compare.csv')

# %%
sns.barplot(x = 'Model', y ="Score %", data = df)
plt.ylim(0, 100)
# Out:
# (0, 100)
